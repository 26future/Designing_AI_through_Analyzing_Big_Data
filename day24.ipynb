# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = plt.subplot()
tips = sns.load_dataset('tips')
tips
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_xlabel('TB')
ax.set_ylabel('Tip')
ax.set_title('Total bill and Tip')
# Out:
# Text(0.5, 1.0, 'Total bill and Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
joint.set_axis_labels(xlabel='TB', ylabel='Tip')

# %%
#이차원 밀집도 그래프
kde, ax = plt.subplots()
sns.kdeplot(data=tips['total_bill'],
            data2=tips['tip'], shade=True)

# %%
kde, ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], shade=True)
ax.set_title('Kernel Density Plot') #제목 바꾸기
# Out:
# Text(0.5, 1.0, 'Kernel Density Plot')

# %%
#barplot
ax = plt.subplots()
sns.barplot(x='time', y='total_bill', data=tips)

# %%
#boxplot
ax = plt.subplots()
sns.boxplot(x='total_bill', data=tips)

# %%
ax = plt.subplots()
sns.boxplot(x='total_bill', data=tips, orient='v') #세로 방향으로 출력

# %%
sns.boxplot(x='day',y='total_bill', data=tips)

# %%
sns.boxplot(x='day',y='total_bill', data=tips, hue='smoker') 
#속성에 따라 한번 더 나눔. 변수를 그룹화

# %%
sns.boxplot(x='day',y='total_bill', data=tips, hue='smoker',palette='Set3')
#seaborn.pydata.org => seaborn tutorial

# %%
sns.boxplot(x='day',y='total_bill', data=tips, hue='smoker',palette='Set3')
sns.swarmplot(x='day',y='total_bill', data=tips) #데이터를 직접 표시

# %%
#violinplot
ax = plt.subplots()
sns.violinplot(x='time', y='total_bill', data=tips)

# %%
#관계그래프
sns.pairplot(tips)

# %%
pg = sns.PairGrid(tips)
pg.map_upper(sns.regplot) #대각요소를 기준으로 위쪽
pg.map_lower(sns.kdeplot) #대각요소를 기준으로 아래쪽
pg.map_diag(sns.distplot, rug=True) #대각요소

# %%
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
flights = sns.load_dataset('flights')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = iris.petal_length.values #array 형태로 값 출력
sns.rugplot(x)

# %%
sns.kdeplot(x)

# %%
sns.distplot(x, kde=False, rug=True)

# %%
#countplot: 각 종류별 데이터가 얼마나 있는지 표시
sns.countplot(x='class', data=titanic)

# %%
sns.countplot(x='day', data=tips)

# %%
"""
1차원 데이터: 실수값, 실수분포 플롯
             (커널밀도, 러그, rugplot, kdeplot, distplot)
countplot: 카테고리별 데이터가 얼마나 있는지 나타낼때 

다차원 데이터(변수가 여러개)
->2차원 실수형 데이터: 스캐터플롯(joint)
->3차원 이상의 실수형 데이터: pairplot(그리드 형태로 출력)
 (만약 카테고리형 데이터가 포함되어 있다면 hue속성을 지정)

->2차원 카테고리형 데이터: heatmap
->2차원 실수값, 카테고리형 데이터가 섞여있을 때: bar, box, point, violin, swarm plot
"""

# %%
#2차원, 연속적인 실수값=> scatter plot(joint)
sns.jointplot(x='sepal_length' , y='sepal_width' , data=iris, kind='scatter')

# %%
sns.jointplot(x='sepal_length' , y='sepal_width' , data=iris, kind='kde')

# %%
#3차원 이상 데이터
sns.pairplot(iris, hue='species', markers=['o','s','D'])

# %%
#2차원데이터, 모든 값이 카테고리형
#heatmap 
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_size = titanic.pivot_table(index='class', columns='sex', aggfunc='size')
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size, annot=True, fmt='d', cmap=sns.light_palette('red'))

# %%
#2차원 데이터. 실수, 카테고리가 섞임
sns.barplot(x='day', y='total_bill', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
sns.violinplot(x='day', y='total_bill', data=tips)

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)

# %%
#요일별, 성별 전체 팁의 히스토그램(barplot)
# x:목/금/토/일
# y:total_bill
# data: tips
sns.barplot(x='day', y='total_bill', data=tips, hue='sex')

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex')
plt.legend(loc=1) #범례 위치 변경

# %%
flights.head()
fp = flights.pivot('month','year','passengers') # (행,열,데이터)
sns.heatmap(fp, linewidths=1, annot=True, fmt='d')

# %%
df = pd.DataFrame(np.random.randn(100,3),   #100행3열
                  index=pd.date_range('1/28/2020', periods=100),
                  columns=['A','B','C']).cumsum()

# %%
df.plot()

# %%
iris.sepal_length[:20].plot(kind='bar', rot=90)
iris.sepal_length[:20].plot.bar(rot=0)

# %%
df2 = iris.groupby(iris.species).mean()
df2
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.plot.bar(rot=0)

# %%
df = titanic.pclass.value_counts()
df.plot.pie(autopct='%.2f%%')

# %%
iris.plot.hist()
iris.plot.kde()

# %%
#선형대수
"""
데이터 개수, 형태에 따라서
스칼라(숫자1개), 벡터(순서가 있는 숫자 여러개), 
행렬(벡터가 여러개인 데이터 집합), 
텐서(같은 크기의 행렬이 여러개 있는 것)
"""
from sklearn.datasets import load_iris
iris = load_iris()
iris.data[0,:]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
#넘파이: 선형대수 문제 해결 사용
x1 = np.array([[5.1],[3.1],[1.4],[0.2]])
x1
#4차원 벡터, 2차원 배열로 표기
np.array([5.1,3.1,1.4,0.2])
# Out:
# array([5.1, 3.1, 1.4, 0.2])

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
# digits

samples = [0,10,20,30,1,11,21,31]

# %%
d=[]
for i in range(8):
    d.append(digits.images[samples[i]])

# %%
plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(d[i], cmap=plt.cm.bone_r) #gray scale
    plt.title('image{}'.format(i+1))
    plt.grid(False) #안내선 제거
    plt.xticks([]) #x축의 값 이름 제거
    plt.yticks([]) #y축의 값 이름 제거

# %%
#2차원 이미지 => 64차원 데이터 => 1차원 벡터

# %%
d[0].shape
# Out:
# (8, 8)

# %%
# 벡터의 내적을 이용한 유사 이미지 검색
v=[]
for i in range(8):
    v.append(d[i].reshape(64,1))


plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(v[i], cmap=plt.cm.bone_r) 
    plt.title('vector{}'.format(i+1))
    plt.grid(False) 
    plt.xticks([]) 
    plt.yticks([])

# %%
#행렬
# [x11 x12 x13 x14
#  x11 x12 x13 x14
#  x11 x12 x13 x14
#  x11 x12 x13 x14]

a = np.array([[10,20,30],[40,50,60]])
a
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
#텐서: 같은 크기의 행렬이 여러 개 묶여 있는 것
#다차원 배열

from scipy import misc
img = misc.face()
img.shape #(768, 1024, 3) 크기를 갖는 3차원 텐서
# Out:
# (768, 1024, 3)

# %%
plt.subplot(221) #2*2로 나눔, 1번째 위치에 이미지 출력
plt.imshow(img, cmap=plt.cm.gray)
plt.axis('off') #axis의 이름 제거

plt.subplot(222)
plt.imshow(img[:,:,2], cmap=plt.cm.gray)
plt.axis('off')

plt.subplot(223)
plt.imshow(img[:,:,2], cmap=plt.cm.gray)
plt.axis('off')

plt.subplot(224)
plt.imshow(img[:,:,2], cmap=plt.cm.gray)
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %%
#두 벡터와 행렬에서 같은 위치에 있는 요소끼리
#덧셈/뺄셈 수행 => element wise(요소간 연산)
x = np.array([1,2])
y = np.array([3,4])
x+y #두 벡터간 덧셈 연산
x-y #두 벡터간 뺄셈 연산
# Out:
# array([-2, -2])

# %%
# 스칼라와 벡터/행렬간 곱셈

#선형조합: 벡터/행렬에 스칼라 값을 곱한 후, 더하거나 뺀 것을
#벡터/행렬의 선형조합이라고 함

#내적: 두 벡터의 곱셈(dot)
#두 벡터의 차원이 같아야 함
#행벡터 * 열벡터
#내적 결과는 스칼라

# %%
x = np.array([[1],[2],[3]])
x
y = np.array([[4],[5],[6]])
y
# np.dot(x.T,y)
x.T@y
# Out:
# array([[32]])

# %%
#데이터 벡터, 가중치 벡터 => 데이터벡터의 가중치 합

# %%
"""
벡터의 내적은 두 벡터의 유사도를 계산하는데 활용
유사도? 두 벡터가 닮은 정도 
코사인 유사도?
"""

# %%
#네 개의 벡터 간의 유사도 => d1과 가장 유사도가 높은 이미지 찾기
#유사도 => 내적을 통해서 구할 수 있음
digits = load_digits()
d1 = digits.images[0]
d2 = digits.images[10]
d3 = digits.images[1]
d4 = digits.images[11]

v1 = d1.reshape(64,1)
v2 = d2.reshape(64,1)
v3 = d3.reshape(64,1)
v4 = d4.reshape(64,1)

# %%
#시각화
plt.figure(figsize=(9,9)) #1당 72pix
import matplotlib.gridspec as gridspec

# %%
gs = gridspec.GridSpec(1,8,height_ratios=[1],width_ratios=[9,1,9,1,9,1,9,1])

# %%
for i in range(4):
    plt.subplot(gs[2*i])
    plt.imshow(eval('d'+str(i+1)), cmap=plt.cm.bone_r)
    plt.subplot(gs[2*i+1])
    plt.imshow(eval('v'+str(i+1)), cmap=plt.cm.bone_r)

# %%
v1 #0
v1.shape
v2.shape
# v1@v2 #error
(v1.T@v2)[0][0] #3064: v1, v2 벡터간 내적한 값
(v1.T@v3)[0][0] #1866: v1, v3 벡터간 내적한 값
(v1.T@v4)[0][0] #1883: v1, v4 벡터간 내적한 값
# v1과 가장 유사한 벡터: v2
# Out:
# 1883.0

# %%
#v2,v3,v4간 내적
np.dot(v2.T, v3) #2421
np.dot(v2.T, v4) #2479
np.dot(v3.T, v4) #3661
# v3와 v4가 가장 유사한 이미지
# Out:
# array([[3661.]])

# %%
#1-(1)

p = np.array([[100],[80],[50]])
n = np.array([[3],[4],[5]])

#1-(2)
np.dot(p.T,n)
# Out:
# array([[870]])

# %%
#2

from sklearn.datasets import load_digits
X = load_digits().data
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
#2-(1)

d1 = X[0]
d10 = X[9]
d1.shape

v1 = d1.reshape(64,1)
v10 = d10.reshape(64,1)

np.dot(v1.T,v10)

#2807
# Out:
# array([[2807.]])

# %%
#2-(2)

len(X)
X.shape
# Out:
# (1797, 64)

# %%
v=[]
res=[]
for i in range(1797):
    for j in range(1797):
        v.append(X[i].reshape(64,1))
        if i<=j:
            continue
        else:
            res.append(np.dot(v[i].T, v[j]))
print(len(res))
# Out:
# 1613706

# %%
#4

ax = np.array([[2,4,1,2,1],
               [3,4,2,3,3],
               [2,4,1,2,2],
               [4,4,4,4,2],
               [4,2,3,3,2]])
ax[0,0] = 1
ax
# Out:
# array([[1, 4, 1, 2, 1],
#        [3, 4, 2, 3, 3],
#        [2, 4, 1, 2, 2],
#        [4, 4, 4, 4, 2],
#        [4, 2, 3, 3, 2]])

# %%
for i in range(5):
    for j in range(1,4):
        if ax[i,j-1] == ax[i,j]==ax[i,j+1]:
            ax[i,j-1] = 7
            ax[i,j] = 7
            ax[i,j+1] = 7
    for j in range(1,2):
        if ax[i,j-1] == ax[i,j] == ax[i,j+1] == ax[i,j+2]:
            ax[i,j-1] = 7
            ax[i,j] = 7
            ax[i,j+1] = 7
            ax[i,j+2] = 7
    
ax
# Out:
# array([[1, 4, 1, 2, 1],
#        [3, 4, 2, 3, 3],
#        [2, 4, 1, 2, 2],
#        [7, 7, 7, 4, 2],
#        [4, 2, 3, 3, 2]])

# %%
ax
# Out:
# array([[1, 4, 1, 2, 1],
#        [3, 4, 2, 3, 3],
#        [2, 4, 1, 2, 2],
#        [4, 4, 4, 4, 2],
#        [4, 2, 3, 3, 2]])

# %%
#가로
A = pd.DataFrame(ax)
for i in range(5):
    if (A[i,0]==A[i,1]==A[i,2] or A[i,1]==A[i,2]==A[i,3] or A[i,2]==A[i,3]==A[i,4])
       or :
        
        
    elif A[i,0]==A[i,1]==A[i,2]==A[i,3] or  A[i,1]==A[i,2]==A[i,3]==A[i,4]:
    
    elif A[i,0]==A[i,1]==A[i,2]==A[i,3]==A[i,4]:
# Out:
#   File "<ipython-input-78-3e1d71851489>", line 7
#     elif A[i,0]==A[i,1]==A[i,2]==A[i,3] or  A[i,1]==A[i,2]==A[i,3]==A[i,4]:
#        ^
# IndentationError: expected an indented block

# %%
ax
# Out:
# array([[1, 4, 1, 2, 1],
#        [3, 4, 2, 3, 3],
#        [2, 4, 1, 2, 2],
#        [4, 4, 4, 4, 2],
#        [4, 2, 3, 3, 2]])

# %%
import re

# %%
ax
for i in range(5):
    for j in range(1,5):
        if j
# Out:
# [1 4 1 2 1]
# [1 4 1 2 1]
# [1 4 1 2 1]
# [1 4 1 2 1]
# [1 4 1 2 1]
# [3 4 2 3 3]
# [3 4 2 3 3]
# [3 4 2 3 3]
# [3 4 2 3 3]
# [3 4 2 3 3]
# [2 4 1 2 2]
# [2 4 1 2 2]
# [2 4 1 2 2]
# [2 4 1 2 2]
# [2 4 1 2 2]
# [4 4 4 4 2]
# [4 4 4 4 2]
# [4 4 4 4 2]
# [4 4 4 4 2]
# [4 4 4 4 2]
# [4 2 3 3 2]
# [4 2 3 3 2]
# [4 2 3 3 2]
# [4 2 3 3 2]
# [4 2 3 3 2]
