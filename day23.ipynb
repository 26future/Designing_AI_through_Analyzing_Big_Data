# %%
# 코랩(colab): 주피터를 구글서버에서 동작
#     ->웹브라우저, 공유, 데이터분석 패키지가 설치
#     ->GPU 사용
#     ->구글 로그인 -> colab.research.com

# %%
# matplotlib.org

# %%
import numpy as np
import matplotlib.pyplot as plt


def koch_snowflake(order, scale=10):
    """
    Return two lists x, y of point coordinates of the Koch snowflake.

    Arguments
    ---------
    order : int
        The recursion depth.
    scale : float
        The extent of the snowflake (edge length of the base triangle).
    """
    def _koch_snowflake_complex(order):
        if order == 0:
            # initial triangle
            angles = np.array([0, 120, 240]) + 90
            return scale / np.sqrt(3) * np.exp(np.deg2rad(angles) * 1j)
        else:
            ZR = 0.5 - 0.5j * np.sqrt(3) / 3

            p1 = _koch_snowflake_complex(order - 1)  # start points
            p2 = np.roll(p1, shift=-1)  # end points
            dp = p2 - p1  # connection vectors

            new_points = np.empty(len(p1) * 4, dtype=np.complex128)
            new_points[::4] = p1
            new_points[1::4] = p1 + dp / 3
            new_points[2::4] = p1 + dp * ZR
            new_points[3::4] = p1 + dp / 3 * 2
            return new_points

    points = _koch_snowflake_complex(order)
    x, y = points.real, points.imag
    return x, y

# %%
x, y = koch_snowflake(order=5)

plt.figure(figsize=(8, 8))
plt.axis('equal')
plt.fill(x, y)
plt.show()

# %%
import matplotlib as mpl
# import matplotlib.pyplot as plt
import matplotlib.pylab as plt
#pylab: 수치해석 s/w -> 시각화 명령 -> 그대로 사용

# %%
# %matplotlib inline
#노트북 내부에 이미지 출력 명령

# %%
#선(line plot)
plt.title('plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('plot')
plt.plot([10,20,30,40],[1,4,9,16], 'rs--') #x축 설정, r:red color, s:data mark, --:선의 스타일
plt.xlabel('x axis')
plt.ylabel('y axis')
    
plt.show()

# %%
plt.title('plot')
plt.plot([10,20,30,40],[1,4,9,16], c='b', lw=5, ls='--', marker='o', ms=15) #c:color, lw:라인 두께, ls:선 스타일, 
                                                                             #marker:데이터 표시, ms:marker 크기
plt.xlabel('x axis')
plt.ylabel('y axis')
    
plt.show()

# %%
#틱설정:플롯에서 축의 위치 표시 지점
#xtickcs, yticks

# %%
np.linspace(0,10,5) #0~10을 5개 구간으로 나눔
# np.pi
x = np.linspace(-np.pi,np.pi,250)
c = np.cos(x)
plt.plot(x,c)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1,0,1])
plt.show()

# %%
t = np.arange(0,5,0.2)
t
plt.plot(t,t,'r--', t,0.5*t**2, 'bs:')

# %%
x = np.linspace(-np.pi,np.pi,250)
c,s = np.cos(x), np.sin(x)
plt.plot(x,c, ls='--',label='cosine')
plt.plot(x,s,ls=':', label='sine' )
plt.legend(loc=2) #각 선이 어떤 데이터를 나타내는지 표시
#loc=0 :자동적으로 가장 적절한 위치에 범례 출력
plt.show()

# %%
np.linspace(-np.pi, np.pi,250)
c,s = np.cos(x), np.sin(x)
plt.plot(x,c,'--', x,s, '--')
plt.legend(loc=2,labels=['cosine','sine'])

# %%
#figure(종이), axes(플롯), axis(축)
#ex)종이(figure)를 반으로 접어서(axes)
#각 axes에 2차원 그림을 출력(axis)

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))
plt.show()

# %%
# subplot(2,1,1)   2행1열 중 첫번째 위치(윗칸)
# subplot(2,1,2)   2행1열 중 두번째 위치(아래칸)
x1 = np.linspace(0.0,5.0)
x2 = np.linspace(0.0,2.0)
y1 = np.cos(2*np.pi*x1)*np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1,y1, 'yo-')
plt.title('table1') #title 지정

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2, 'r.-')
plt.title('table2')

plt.tight_layout()  #두 그래프 사이의 간격 조정

# %%
# fig, axes = plt.subplots(2,2) 와 동일

# %%
import matplotlib

from matplotlib import font_manager, rc
import platform
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings("ignore")

# %%
#bar chart

y = [2,3,1]
x = np.arange(len(y)) #[0,1,2]
plt.bar(x,y)
plt.xticks(x, ['X', 'Y', 'Z']) #x축의 각 값의 이름 설정
plt.xlabel('가나다') #x축의 이름 설정
plt.show()

# %%
#stemplot (푝이 없는 바)

x = np.linspace(0.1,2*np.pi,10)
plt.stem(x,np.cos(x),'-.')
plt.show()

# %%
#pie chart

labels = ['취업','결혼','출산','건강']
sizes = [15,30,45,10]
colors = ['yellow','gold','skyblue','lightcoral']
ex = (0.1,0,0,0) #한 부분을 부각
plt.pie(sizes,explode=ex, autopct='%.1f %%', labels=labels, colors=colors, shadow=True, startangle=90)
#autopct='%.1f': 소수 이하 첫째짜리까지 출력
plt.show()

# %%
#hist: histogram 출력

x = np.random.randn(100)
arr, bins, patches = plt.hist(x,bins=10)
plt.show()

# %%
arr #각 구간의 데이터 개수
bins
# Out:
# array([-2.77259276, -2.26494181, -1.75729087, -1.24963992, -0.74198897,
#        -0.23433803,  0.27331292,  0.78096386,  1.28861481,  1.79626575,
#         2.3039167 ])

# %%
#스캐터플롯: 상관관계
x = np.random.normal(0,1,100) #정규분포를 따르는 0부터 1사이의 난수 100개
y = np.random.normal(0,1,100)
plt.scatter(x,y)
plt.show()

# %%
#3차원 데이터(점의 크기나 색깔로 고차원의 데이터 표시)
w = np.random.randn(30)
x = np.random.randn(30)
y = np.random.randn(30)
z = np.pi*(10*np.random.randn(30))**2
plt.scatter(w,x, c=y, s=z)
plt.show()

# %%
from sklearn.datasets import load_digits

# %%
#MNIST 이미지
digits = load_digits()
x = digits.images[0] #0를 이미지화
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(x,cmap=plt.cm.bone_r)
dir(plt.cm) #색깔 속성
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'LUTSIZE',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
# ...

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset('anscombe') #데이터는 다르지만 통계치(평균, 분산)가 동일 => 데이터 시각화의 필요성

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
d1 = anscombe[anscombe['dataset']=='I']
plt.plot(d1['x'],d1['y'])

# %%
#점으로 출력
plt.plot(d1['x'],d1['y'],'o')

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

plt.plot(d1['x'],d1['y'])

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(d1['x'],d1['y'],'o')
axes2.plot(d2['x'],d2['y'],'o')
axes3.plot(d3['x'],d3['y'],'o')
axes4.plot(d4['x'],d4['y'],'o')

fig

# %%
axes1.set_title('dataset1')
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')

fig.suptitle('Anscombe data') #전체 figure에 대한 title
fig.tight_layout() #그래프 사이의 간격 조정

fig

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1

# %%
#histogram으로 total_bill 나타내기
axes1.hist(tips['total_bill'], bins=6)
fig

# %%
scPlot = plt.figure()
axes1 = scPlot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])

# %%
#boxplot
boxPlot = plt.figure()
axes1 = boxPlot.add_subplot(1,1,1)
tips[tips[tips['sex']=='Female']['tip'], #성별이 '여성'인 데이터에서 'tip'열 추출
     tips[tips['sex']=='Male']['tip'], labels=['Female','Male'] ]
# Out:
#   File "<ipython-input-143-f00ffb43a539>", line 5
#     tips[tips['sex']=='Male']['tip'], labels=['Female','Male'] ]
#                                             ^
# SyntaxError: invalid syntax

# %%
tips[tips['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips[tips['sex']=='Female']['tip']
# Out:
# 0      1.01
# 4      3.61
# 11     5.00
# 14     3.02
# 16     1.67
#        ...
# 226    2.00
# 229    2.88
# 238    4.67
# 240    2.00
# 243    3.00
# Name: tip, Length: 87, dtype: float64
